# %% [markdown]
# # ztm48

# %%
import pandas as pd

# %%
# 2 main data types
series = pd.Series(['BMW', 'Toyota', 'Honda'])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series - 1-dimensional

# %%
colors = pd.Series(['Red', 'Blue', 'White'])
colors
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# dataframe = 2-dimensional
car_data = pd.DataFrame({'Car make': series, 'color': colors})
car_data
# Out:
#   Car make  color
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
# import data
car_sales = pd.read_csv('car-sales.csv')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# export a dataframe
car_sales.to_csv('exported-car-sales1.csv', index=False)

# %%
exported_car_sales = pd.read_csv('exported-car-sales1.csv')
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
import_from_git = pd.read_csv('https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv')
import_from_git
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# # ztm50 - describing

# %%
# describe data
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000, 1500, 111250])
car_prices.mean()
# Out:
# 38583.333333333336

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales['Doors'].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # ztm 51 - viewing and selecting

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc

animals = pd.Series(['cat', 'dog', 'bird', 'panda', 'snake'], index=[0, 3, 9, 8, 3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
# .iloc = position, .loc = index
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.head(4)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales['Colour']
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales.Colour
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales['Make'] == 'Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales['Odometer (KM)'] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %% [markdown]
# # ztm52 - view and select 2

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales['Make'], car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# groupby
car_sales.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
car_sales['Odometer (KM)'].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales['Odometer (KM)'].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales['Price'].dtype
# Out:
# dtype('O')

# %%
car_sales['Price']
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
car_sales['Price'] = car_sales['Price'].str[:6]

# %%
car_sales['Price'] = car_sales['Price'].replace('[\$\,]', '', regex=True).astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5   2200
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales['Price'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # ztm53 - manipulating1

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5   2200
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales['Make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_missing = pd.read_csv('./car-sales-missing-data.csv')
car_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_missing['Odometer'].mean()
# Out:
# 92302.66666666667

# %%
car_missing['Odometer'].fillna(car_missing['Odometer'].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_missing['Odometer'].fillna(car_missing['Odometer'].mean(), inplace=True)

# %%
car_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_missing.dropna(inplace=True)

# %%
car_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_missing = pd.read_csv('./car-sales-missing-data.csv')
car_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_missing_dropped = car_missing.dropna()
car_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_missing_dropped.to_csv('./car-sales-missing-dropped.csv')

# %% [markdown]
# # ztm54 - manipulating2

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5   2200
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
seats_column = pd.Series([5, 5, 5, 5, 5])

# new column called seats
car_sales['Seats'] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  Toyota  White         150043      4   4000    5.0
# 1   Honda    Red          87899      4   5000    5.0
# 2  Toyota   Blue          32549      3   7000    5.0
# 3     BMW  Black          11179      5   2200    5.0
# 4  Nissan  White         213095      4   3500    5.0
# 5  Toyota  Green          99213      4   4500    NaN
# 6   Honda   Blue          45698      4   7500    NaN
# 7   Honda   Blue          54738      4   7000    NaN
# 8  Toyota  White          60000      4   6250    NaN
# 9  Nissan  White          31600      4   9700    NaN

# %%
car_sales['Seats'].fillna(5, inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  Toyota  White         150043      4   4000    5.0
# 1   Honda    Red          87899      4   5000    5.0
# 2  Toyota   Blue          32549      3   7000    5.0
# 3     BMW  Black          11179      5   2200    5.0
# 4  Nissan  White         213095      4   3500    5.0
# 5  Toyota  Green          99213      4   4500    5.0
# 6   Honda   Blue          45698      4   7500    5.0
# 7   Honda   Blue          54738      4   7000    5.0
# 8  Toyota  White          60000      4   6250    5.0
# 9  Nissan  White          31600      4   9700    5.0

# %%
# column from py list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]
car_sales['Fuel per 100KM'] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM
# 0  Toyota  White         150043      4   4000    5.0             7.5
# 1   Honda    Red          87899      4   5000    5.0             9.2
# 2  Toyota   Blue          32549      3   7000    5.0             5.0
# 3     BMW  Black          11179      5   2200    5.0             9.6
# 4  Nissan  White         213095      4   3500    5.0             8.7
# 5  Toyota  Green          99213      4   4500    5.0             4.7
# 6   Honda   Blue          45698      4   7500    5.0             7.6
# 7   Honda   Blue          54738      4   7000    5.0             8.7
# 8  Toyota  White          60000      4   6250    5.0             3.0
# 9  Nissan  White          31600      4   9700    5.0             4.5

# %%
car_sales['Total fuel used'] = car_sales['Odometer (KM)']/100 * car_sales['Fuel per 100KM']
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0             7.5
# 1   Honda    Red          87899      4   5000    5.0             9.2
# 2  Toyota   Blue          32549      3   7000    5.0             5.0
# 3     BMW  Black          11179      5   2200    5.0             9.6
# 4  Nissan  White         213095      4   3500    5.0             8.7
# 5  Toyota  Green          99213      4   4500    5.0             4.7
# 6   Honda   Blue          45698      4   7500    5.0             7.6
# 7   Honda   Blue          54738      4   7000    5.0             8.7
# 8  Toyota  White          60000      4   6250    5.0             3.0
# 9  Nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used
# 0        11253.225
# 1         8086.708
# 2         1627.450
# 3         1073.184
# 4        18539.265
# 5         4663.011
# 6         3473.048
# 7         4762.206
# 8         1800.000
# ...

# %%
# create a column from a single value
car_sales['Number of wheels'] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0             7.5
# 1   Honda    Red          87899      4   5000    5.0             9.2
# 2  Toyota   Blue          32549      3   7000    5.0             5.0
# 3     BMW  Black          11179      5   2200    5.0             9.6
# 4  Nissan  White         213095      4   3500    5.0             8.7
# 5  Toyota  Green          99213      4   4500    5.0             4.7
# 6   Honda   Blue          45698      4   7500    5.0             7.6
# 7   Honda   Blue          54738      4   7000    5.0             8.7
# 8  Toyota  White          60000      4   6250    5.0             3.0
# 9  Nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used  Number of wheels
# 0        11253.225                 4
# 1         8086.708                 4
# 2         1627.450                 4
# 3         1073.184                 4
# ...

# %%
car_sales['Passed road safety'] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0             7.5
# 1   Honda    Red          87899      4   5000    5.0             9.2
# 2  Toyota   Blue          32549      3   7000    5.0             5.0
# 3     BMW  Black          11179      5   2200    5.0             9.6
# 4  Nissan  White         213095      4   3500    5.0             8.7
# 5  Toyota  Green          99213      4   4500    5.0             4.7
# 6   Honda   Blue          45698      4   7500    5.0             7.6
# 7   Honda   Blue          54738      4   7000    5.0             8.7
# 8  Toyota  White          60000      4   6250    5.0             3.0
# 9  Nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used  Number of wheels  Passed road safety
# 0        11253.225                 4                True
# 1         8086.708                 4                True
# ...

# %%
car_sales.dtypes
# Out:
# Make                   object
# Colour                 object
# Odometer (KM)           int64
# Doors                   int64
# Price                   int32
# Seats                 float64
# Fuel per 100KM        float64
# Total fuel used       float64
# Number of wheels        int64
# Passed road safety       bool
# dtype: object

# %%
car_sales['Car?'] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0             7.5
# 1   Honda    Red          87899      4   5000    5.0             9.2
# 2  Toyota   Blue          32549      3   7000    5.0             5.0
# 3     BMW  Black          11179      5   2200    5.0             9.6
# 4  Nissan  White         213095      4   3500    5.0             8.7
# 5  Toyota  Green          99213      4   4500    5.0             4.7
# 6   Honda   Blue          45698      4   7500    5.0             7.6
# 7   Honda   Blue          54738      4   7000    5.0             8.7
# 8  Toyota  White          60000      4   6250    5.0             3.0
# 9  Nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used  Number of wheels  Passed road safety  Car?
# 0        11253.225                 4                True  True
# 1         8086.708                 4                True  True
# ...

# %%
car_sales.drop('Car?', axis=1, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0             7.5
# 1   Honda    Red          87899      4   5000    5.0             9.2
# 2  Toyota   Blue          32549      3   7000    5.0             5.0
# 3     BMW  Black          11179      5   2200    5.0             9.6
# 4  Nissan  White         213095      4   3500    5.0             8.7
# 5  Toyota  Green          99213      4   4500    5.0             4.7
# 6   Honda   Blue          45698      4   7500    5.0             7.6
# 7   Honda   Blue          54738      4   7000    5.0             8.7
# 8  Toyota  White          60000      4   6250    5.0             3.0
# 9  Nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used  Number of wheels  Passed road safety
# 0        11253.225                 4                True
# 1         8086.708                 4                True
# ...

# %% [markdown]
# # ztm55 - manipulating3

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0             7.5
# 1   Honda    Red          87899      4   5000    5.0             9.2
# 2  Toyota   Blue          32549      3   7000    5.0             5.0
# 3     BMW  Black          11179      5   2200    5.0             9.6
# 4  Nissan  White         213095      4   3500    5.0             8.7
# 5  Toyota  Green          99213      4   4500    5.0             4.7
# 6   Honda   Blue          45698      4   7500    5.0             7.6
# 7   Honda   Blue          54738      4   7000    5.0             8.7
# 8  Toyota  White          60000      4   6250    5.0             3.0
# 9  Nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used  Number of wheels  Passed road safety
# 0        11253.225                 4                True
# 1         8086.708                 4                True
# ...

# %%
car_sales_shuffled = car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 5  Toyota  Green          99213      4   4500    5.0             4.7
# 7   Honda   Blue          54738      4   7000    5.0             8.7
# 1   Honda    Red          87899      4   5000    5.0             9.2
# 4  Nissan  White         213095      4   3500    5.0             8.7
# 2  Toyota   Blue          32549      3   7000    5.0             5.0
# 0  Toyota  White         150043      4   4000    5.0             7.5
# 3     BMW  Black          11179      5   2200    5.0             9.6
# 8  Toyota  White          60000      4   6250    5.0             3.0
# 9  Nissan  White          31600      4   9700    5.0             4.5
# 6   Honda   Blue          45698      4   7500    5.0             7.6
#
#    Total fuel used  Number of wheels  Passed road safety
# 5         4663.011                 4                True
# 7         4762.206                 4                True
# ...

# %%
# only select 20% of data
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 6   Honda   Blue          45698      4   7500    5.0             7.6
# 2  Toyota   Blue          32549      3   7000    5.0             5.0
#
#    Total fuel used  Number of wheels  Passed road safety
# 6         3473.048                 4                True
# 2         1627.450                 4                True

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  Green          99213      4   4500    5.0             4.7
# 1   Honda   Blue          54738      4   7000    5.0             8.7
# 2   Honda    Red          87899      4   5000    5.0             9.2
# 3  Nissan  White         213095      4   3500    5.0             8.7
# 4  Toyota   Blue          32549      3   7000    5.0             5.0
# 5  Toyota  White         150043      4   4000    5.0             7.5
# 6     BMW  Black          11179      5   2200    5.0             9.6
# 7  Toyota  White          60000      4   6250    5.0             3.0
# 8  Nissan  White          31600      4   9700    5.0             4.5
# 9   Honda   Blue          45698      4   7500    5.0             7.6
#
#    Total fuel used  Number of wheels  Passed road safety
# 0         4663.011                 4                True
# 1         4762.206                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0             7.5
# 1   Honda    Red          87899      4   5000    5.0             9.2
# 2  Toyota   Blue          32549      3   7000    5.0             5.0
# 3     BMW  Black          11179      5   2200    5.0             9.6
# 4  Nissan  White         213095      4   3500    5.0             8.7
# 5  Toyota  Green          99213      4   4500    5.0             4.7
# 6   Honda   Blue          45698      4   7500    5.0             7.6
# 7   Honda   Blue          54738      4   7000    5.0             8.7
# 8  Toyota  White          60000      4   6250    5.0             3.0
# 9  Nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used  Number of wheels  Passed road safety
# 0        11253.225                 4                True
# 1         8086.708                 4                True
# ...

# %%
car_sales['Odometer (KM)'] = car_sales['Odometer (KM)'].apply(lambda x: x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White      93776.875      4   4000    5.0             7.5
# 1   Honda    Red      54936.875      4   5000    5.0             9.2
# 2  Toyota   Blue      20343.125      3   7000    5.0             5.0
# 3     BMW  Black       6986.875      5   2200    5.0             9.6
# 4  Nissan  White     133184.375      4   3500    5.0             8.7
# 5  Toyota  Green      62008.125      4   4500    5.0             4.7
# 6   Honda   Blue      28561.250      4   7500    5.0             7.6
# 7   Honda   Blue      34211.250      4   7000    5.0             8.7
# 8  Toyota  White      37500.000      4   6250    5.0             3.0
# 9  Nissan  White      19750.000      4   9700    5.0             4.5
#
#    Total fuel used  Number of wheels  Passed road safety
# 0        11253.225                 4                True
# 1         8086.708                 4                True
# ...
