# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
panda = mpimg.imread('./numpy-panda.png')
imgplot = plt.imshow(panda)
plt.show()

# %%
type(panda)
# Out:
# numpy.ndarray

# %%
panda.size, panda.shape, panda.ndim
# Out:
# (24465000, (2330, 3500, 3), 3)

# %%
panda[:1]
# Out:
# array([[[0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         [0.05490196, 0.10588235, 0.06666667],
#         ...,
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765],
#         [0.16470589, 0.12941177, 0.09411765]]], dtype=float32)

# %%
car = mpimg.imread('./numpy-car-photo.png')
imgplot = plt.imshow(car)
plt.show()

# %%
type(car)
# Out:
# numpy.ndarray

# %%
car.size, car.shape, car.ndim
# Out:
# (991300, (431, 575, 4), 3)

# %%
car[:1]
# Out:
# array([[[0.5019608 , 0.50980395, 0.4862745 , 1.        ],
#         [0.3372549 , 0.34509805, 0.30588236, 1.        ],
#         [0.20392157, 0.21568628, 0.14901961, 1.        ],
#         ...,
#         [0.64705884, 0.7058824 , 0.54901963, 1.        ],
#         [0.59607846, 0.63529414, 0.45882353, 1.        ],
#         [0.44705883, 0.47058824, 0.3372549 , 1.        ]]], dtype=float32)

# %%
dog = mpimg.imread('./numpy-dog-photo.png')
imgplot = plt.imshow(dog)
plt.show()

# %%
type(dog)
# Out:
# numpy.ndarray

# %%
dog.size, dog.shape, dog.ndim
# Out:
# (993600, (432, 575, 4), 3)

# %%
dog[:1]
# Out:
# array([[[0.70980394, 0.80784315, 0.88235295, 1.        ],
#         [0.72156864, 0.8117647 , 0.8862745 , 1.        ],
#         [0.7411765 , 0.8156863 , 0.8862745 , 1.        ],
#         ...,
#         [0.49803922, 0.6862745 , 0.8392157 , 1.        ],
#         [0.49411765, 0.68235296, 0.8392157 , 1.        ],
#         [0.49411765, 0.68235296, 0.8352941 , 1.        ]]], dtype=float32)
